# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
from pandas import json_normalize
import os
Home="/content/drive/MyDrive/aware_train_2022"
classes_score=json.load(open(os.path.join(Home, "class_scores.json")))
#dummy_run=json.load(open(os.path.join(Home, "dummy_run.json"))) # delimiter error
gt_train=json.load(open(os.path.join(Home, "gt_train.json")))
gt_val=json.load(open(os.path.join(Home, "gt_val.json")))
pred_test=json.load(open(os.path.join(Home, "predictions_test.json")))
pred_train=json.load(open(os.path.join(Home, "predictions_train.json")))
pred_val=json.load(open(os.path.join(Home, "predictions_val.json")))

# %%
#classes_score format VC{situation[4]}
print("Classes_Scores")
print("total number of scenarios",len(classes_score))
# Out:
# Classes_Scores
# total number of scenarios 266

# %%
#gt_train format userid{situation[4]}
print("Actual Train Outputs")
print("total number of userids in out Trainset",len(gt_train))
# Out:
# Actual Train Outputs
# total number of userids in out Trainset 600

# %%
#gt_val format userid{situation[4]}
print("Actual validation Outputs")
print("total number of userids in out val",len(gt_val))
# Out:
# Actual validation Outputs
# total number of userids in out val 200

# %%
#pred_train format userid{ userimg {"VC", confidence, points[4]}
print("Actual Train Input")
print("total number of userids in Trainset",len(pred_train))
maxVC=0
pred={"Train":pred_train,"val":pred_val,"test":pred_test}
for s,p in pred.items():
  maxVC=0
  for user in p:
    for img in p[user]:
      maxVC=max(maxVC,len(p[user][img]))
  print("number of VC in ",s,maxVC)

for s,p in pred.items():
  maxIMG=0
  for user in p:
    maxIMG=max(maxIMG,len(p[user]))
  print("number of images in ",s,maxIMG)
# Out:
# Actual Train Input
# total number of userids in Trainset 600
# number of VC in  Train 20
# number of VC in  val 17
# number of VC in  test 18
# number of images in  Train 93
# number of images in  val 92
# number of images in  test 94

# %%
#pred_val format userid{ userimg {"VC", confidence, points[4]}
print("Actual Val Input")
print("total number of userids in val",len(pred_val))
print(pred_val["zjn7scaggcdjod7u"]["l9ubiwvo7sqes0ft"][0])
# Out:
# Actual Val Input
# total number of userids in val 200
# VC62 0.348204642534256 0.0 0.16885580122470856 1.0 0.3646084666252136

# %%
print("max number of images for each user , pred_train",max([len(user) for user in pred_train]))
print("max number of images for each user, pred_val ",max([len(user) for user in pred_val]))
print("max number of images for each user, pred_val ",max([len(user) for user in pred_val]))
# Out:
# max number of images for each user , pred_train 16
# max number of images for each user, pred_val  16
# max number of images for each user, pred_val  16

# %%
import numpy
import array
import tensorflow as tf



def getmatrix(user,pred): #for flattened 9columns, append each image { visual_concept{acc,it, bank,wait},confidence,4 points} 
  images=[img for img in pred[user]]
  matrix=[]
  for img in images:
    VCs=[s for s in pred[user][img]] #gets the strings{VC,confidence,4 points} inside image
    for VC in VCs:
      row=VC.split(" ")
      VC_name= row[0]
      scores=[]
      try: #some VC not found in class_score
        scores=[float(classes_score[VC_name]["acc"]),float(classes_score[VC_name]["it"]),float(classes_score[VC_name]["bank"]),float(classes_score[VC_name]["wait"])] #[it for k2,it in classes_score[row[0]].items()]
      except:
        scores=[-1,-1,-1,-1]
      scores=[]
      for i in range(1,2): #if this is 2,3,4,5 are the location coords
        scores.append(float(row[i]))
      matrix.extend(scores[:])
  while(len(matrix)<=3000):
    matrix.extend([-1]*1)
  flatten_list = matrix
  return flatten_list

x_train=[getmatrix(user,pred_train) for user in pred_train]
y_train=[]
y_train1,y_train2,y_train3,y_train4=[],[],[],[]
for user in gt_train:
  y_train.append([float(gt_train[user]["acc"]),float(gt_train[user]["it"]),float(gt_train[user]["bank"]),float(gt_train[user]["wait"])])


x_val=[getmatrix(user,pred_val) for user in pred_val]

y_val=[]
for user in gt_val:
  y_val.append([float(gt_val[user]["acc"]),float(gt_val[user]["it"]),float(gt_val[user]["bank"]),float(gt_val[user]["wait"])])

print("Fit model on training data")

from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import *
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
models = {"ETreeR":ExtraTreesRegressor,
          "RForestR":RandomForestRegressor,
          "GBR":GradientBoostingRegressor}
val = {"ETreeR":[0.5010044342130072,7.023577170121131e-16],"RForestR":[0.498759369775145,0.17990357853684089],"GBR":[0.5037543503228156, 0.1806476008687124]}
def save_result(result,name):
  dictdata={}
  for row,user in zip(result,pred_test):
    dictdata[user]={}
    dictdata[user]["acc"]=float(row[0])
    dictdata[user]["bank"] = float(row[1])
    dictdata[user]["it"] = float(row[2])
    dictdata[user]["wait"] = float(row[3])
  with open('/content/drive/MyDrive/aware_train_2022/output/'+name, 'w') as f:
      json.dump(dictdata, f)
print(val)
for n in models.keys():
  MOR=MultiOutputRegressor(models[n](random_state=0)).fit(x_train, y_train)
  print(n)
  val_err = mean_absolute_error(y_val,MOR.predict(x_val),squared=False)
  err = mean_absolute_error(y_train,MOR.predict(x_train),squared=False)
  print(val_err,",",err)
  if(err<val[n][1] and val_err <val[n][0]):
    print("changed",n)
    val[n][1] = err
    val[n][0] = val_err
    x_test=[getmatrix(user,pred_test) for user in pred_test]
    result_mor=MOR.predict(x_test)
    #save_result(result_mor,n+'.json')
print(val)
# Out:
# Fit model on training data
# {'ETreeR': [0.5010044342130072, 7.023577170121131e-16], 'RForestR': [0.498759369775145, 0.17990357853684089], 'GBR': [0.5037543503228156, 0.1806476008687124]}
# ETreeR
# 0.40270373673080334 , 4.705694023101244e-16
# changed ETreeR
# RForestR
# 0.4040859703900409 , 0.14336548257278603
# changed RForestR
# GBR
# 0.42080292842710815 , 0.20221363104174547
# {'ETreeR': [0.40270373673080334, 4.705694023101244e-16], 'RForestR': [0.4040859703900409, 0.14336548257278603], 'GBR': [0.5037543503228156, 0.1806476008687124]}

# %%
print(7.023577170121131e-16 < 7.023577170121131e-15)
# Out:
# True

# %%
x_test=[getmatrix(user,pred_test) for user in pred_test]
result_mor=MOR.predict(x_test)
def save_result(result,name):
  dictdata={}
  for row,user in zip(result,pred_test):
    dictdata[user]={}
    dictdata[user]["acc"]=str(row[0])
    dictdata[user]["bank"] = str(row[1])
    dictdata[user]["it"] = str(row[2])
    dictdata[user]["wait"] = str(row[3])
  with open('/content/drive/MyDrive/aware_train_2022/output/'+name, 'w') as f:
      json.dump(dictdata, f)
save_result(result_mor,"RForestR.json")

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K




def getmatrix(user,pred): #for flattened 9columns, append each image { visual_concept{acc,it, bank,wait},confidence,4 points} 
  images=[img for img in pred[user]]
  matrix=[]
  for img in images:
    VCs=[s for s in pred[user][img]] #gets the strings{VC,confidence,4 points} inside image
    for VC in VCs:
      row=VC.split(" ")
      VC_name= row[0]
      scores=[]
      try: #some VC not found in class_score
        scores=[float(classes_score[VC_name]["acc"]),float(classes_score[VC_name]["it"]),float(classes_score[VC_name]["bank"]),float(classes_score[VC_name]["wait"])] #[it for k2,it in classes_score[row[0]].items()]
      except:
        scores=[-1,-1,-1,-1]
      # for i in range(1,2):
      #   scores.append(float(row[i]))
      matrix.extend(scores[:])
  while(len(matrix)<=3000):
    matrix.extend([-1]*4)
  flatten_list = matrix
  return flatten_list

x_train=[getmatrix(user,pred_train) for user in pred_train]
y_train=[]
y_train1,y_train2,y_train3,y_train4=[],[],[],[]
for user in gt_train:
  y_train.append([float(gt_train[user]["acc"]),float(gt_train[user]["it"]),float(gt_train[user]["bank"]),float(gt_train[user]["wait"])])


x_val=[getmatrix(user,pred_val) for user in pred_val]

y_val=[]
for user in gt_val:
  y_val.append([float(gt_val[user]["acc"]),float(gt_val[user]["it"]),float(gt_val[user]["bank"]),float(gt_val[user]["wait"])])



DenseModel = Sequential([
    Dense(3000, activation='relu'),
    Dense(2048, activation='relu'),
     Dense(1024, activation='relu'),
     Dense(512, activation='relu'),
     Dense(128, activation='relu'),
     Dense(64, activation='relu'),
    Dense(4)
])

DenseModel.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=Adam(),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

DenseModel.fit(x_train, y_train, epochs=200,validation_data=(x_val,y_val),batch_size=20)
model=DenseModel
print("Validation error: ",mean_squared_error(y_val,model.predict(x_val),squared=False))
print("Train Error",mean_squared_error(y_train,model.predict(x_train),squared=False))
# Out:
# Epoch 1/200
# 30/30 [==============================] - 3s 100ms/step - loss: 3.3604 - root_mean_squared_error: 1.8331 - val_loss: 0.4170 - val_root_mean_squared_error: 0.6457
# Epoch 2/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3397 - root_mean_squared_error: 0.5829 - val_loss: 0.2970 - val_root_mean_squared_error: 0.5450
# Epoch 3/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2696 - root_mean_squared_error: 0.5192 - val_loss: 0.3385 - val_root_mean_squared_error: 0.5818
# Epoch 4/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2618 - root_mean_squared_error: 0.5117 - val_loss: 0.2791 - val_root_mean_squared_error: 0.5283
# Epoch 5/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2651 - root_mean_squared_error: 0.5148 - val_loss: 0.2839 - val_root_mean_squared_error: 0.5329
# Epoch 6/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2606 - root_mean_squared_error: 0.5105 - val_loss: 0.2640 - val_root_mean_squared_error: 0.5138
# Epoch 7/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2375 - root_mean_squared_error: 0.4874 - val_loss: 0.2698 - val_root_mean_squared_error: 0.5195
# Epoch 8/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2334 - root_mean_squared_error: 0.4831 - val_loss: 0.3111 - val_root_mean_squared_error: 0.5577
# Epoch 9/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2359 - root_mean_squared_error: 0.4857 - val_loss: 0.2625 - val_root_mean_squared_error: 0.5124
# Epoch 10/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2216 - root_mean_squared_error: 0.4707 - val_loss: 0.2747 - val_root_mean_squared_error: 0.5241
# Epoch 11/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2167 - root_mean_squared_error: 0.4656 - val_loss: 0.2638 - val_root_mean_squared_error: 0.5136
# Epoch 12/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2188 - root_mean_squared_error: 0.4678 - val_loss: 0.2634 - val_root_mean_squared_error: 0.5133
# Epoch 13/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2099 - root_mean_squared_error: 0.4581 - val_loss: 0.2521 - val_root_mean_squared_error: 0.5021
# Epoch 14/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2036 - root_mean_squared_error: 0.4512 - val_loss: 0.2514 - val_root_mean_squared_error: 0.5014
# Epoch 15/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1990 - root_mean_squared_error: 0.4461 - val_loss: 0.2688 - val_root_mean_squared_error: 0.5185
# Epoch 16/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1902 - root_mean_squared_error: 0.4361 - val_loss: 0.2601 - val_root_mean_squared_error: 0.5100
# Epoch 17/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1924 - root_mean_squared_error: 0.4387 - val_loss: 0.2669 - val_root_mean_squared_error: 0.5167
# Epoch 18/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1889 - root_mean_squared_error: 0.4346 - val_loss: 0.2751 - val_root_mean_squared_error: 0.5245
# Epoch 19/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1905 - root_mean_squared_error: 0.4365 - val_loss: 0.2585 - val_root_mean_squared_error: 0.5084
# Epoch 20/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1768 - root_mean_squared_error: 0.4205 - val_loss: 0.2595 - val_root_mean_squared_error: 0.5094
# Epoch 21/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1630 - root_mean_squared_error: 0.4037 - val_loss: 0.2449 - val_root_mean_squared_error: 0.4948
# Epoch 22/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1562 - root_mean_squared_error: 0.3952 - val_loss: 0.2653 - val_root_mean_squared_error: 0.5150
# Epoch 23/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1469 - root_mean_squared_error: 0.3833 - val_loss: 0.2686 - val_root_mean_squared_error: 0.5182
# Epoch 24/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1621 - root_mean_squared_error: 0.4026 - val_loss: 0.2545 - val_root_mean_squared_error: 0.5045
# Epoch 25/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1466 - root_mean_squared_error: 0.3829 - val_loss: 0.2898 - val_root_mean_squared_error: 0.5383
# Epoch 26/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1400 - root_mean_squared_error: 0.3741 - val_loss: 0.2636 - val_root_mean_squared_error: 0.5135
# Epoch 27/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1331 - root_mean_squared_error: 0.3649 - val_loss: 0.2479 - val_root_mean_squared_error: 0.4979
# Epoch 28/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1328 - root_mean_squared_error: 0.3643 - val_loss: 0.2923 - val_root_mean_squared_error: 0.5407
# Epoch 29/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1364 - root_mean_squared_error: 0.3694 - val_loss: 0.2558 - val_root_mean_squared_error: 0.5058
# Epoch 30/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1197 - root_mean_squared_error: 0.3459 - val_loss: 0.2627 - val_root_mean_squared_error: 0.5125
# Epoch 31/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1319 - root_mean_squared_error: 0.3632 - val_loss: 0.2798 - val_root_mean_squared_error: 0.5289
# Epoch 32/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1230 - root_mean_squared_error: 0.3507 - val_loss: 0.2690 - val_root_mean_squared_error: 0.5187
# Epoch 33/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - val_loss: 0.2586 - val_root_mean_squared_error: 0.5085
# Epoch 34/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1109 - root_mean_squared_error: 0.3330 - val_loss: 0.2718 - val_root_mean_squared_error: 0.5214
# Epoch 35/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1140 - root_mean_squared_error: 0.3377 - val_loss: 0.2576 - val_root_mean_squared_error: 0.5076
# Epoch 36/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1165 - root_mean_squared_error: 0.3413 - val_loss: 0.2777 - val_root_mean_squared_error: 0.5270
# Epoch 37/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1010 - root_mean_squared_error: 0.3178 - val_loss: 0.2947 - val_root_mean_squared_error: 0.5428
# Epoch 38/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0968 - root_mean_squared_error: 0.3112 - val_loss: 0.2594 - val_root_mean_squared_error: 0.5093
# Epoch 39/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0897 - root_mean_squared_error: 0.2995 - val_loss: 0.2891 - val_root_mean_squared_error: 0.5377
# Epoch 40/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1015 - root_mean_squared_error: 0.3185 - val_loss: 0.2648 - val_root_mean_squared_error: 0.5146
# Epoch 41/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0949 - root_mean_squared_error: 0.3080 - val_loss: 0.2676 - val_root_mean_squared_error: 0.5173
# Epoch 42/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0871 - root_mean_squared_error: 0.2951 - val_loss: 0.2888 - val_root_mean_squared_error: 0.5374
# Epoch 43/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0749 - root_mean_squared_error: 0.2737 - val_loss: 0.2640 - val_root_mean_squared_error: 0.5138
# Epoch 44/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0724 - root_mean_squared_error: 0.2691 - val_loss: 0.3104 - val_root_mean_squared_error: 0.5572
# Epoch 45/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0670 - root_mean_squared_error: 0.2588 - val_loss: 0.2984 - val_root_mean_squared_error: 0.5463
# Epoch 46/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0646 - root_mean_squared_error: 0.2542 - val_loss: 0.2971 - val_root_mean_squared_error: 0.5451
# Epoch 47/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0660 - root_mean_squared_error: 0.2569 - val_loss: 0.2919 - val_root_mean_squared_error: 0.5402
# Epoch 48/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0989 - root_mean_squared_error: 0.3144 - val_loss: 0.2691 - val_root_mean_squared_error: 0.5187
# Epoch 49/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0834 - root_mean_squared_error: 0.2889 - val_loss: 0.3443 - val_root_mean_squared_error: 0.5868
# Epoch 50/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0791 - root_mean_squared_error: 0.2812 - val_loss: 0.2950 - val_root_mean_squared_error: 0.5431
# Epoch 51/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0576 - root_mean_squared_error: 0.2399 - val_loss: 0.2861 - val_root_mean_squared_error: 0.5349
# Epoch 52/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0523 - root_mean_squared_error: 0.2288 - val_loss: 0.2899 - val_root_mean_squared_error: 0.5384
# Epoch 53/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0491 - root_mean_squared_error: 0.2216 - val_loss: 0.2935 - val_root_mean_squared_error: 0.5418
# Epoch 54/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0448 - root_mean_squared_error: 0.2116 - val_loss: 0.3015 - val_root_mean_squared_error: 0.5491
# Epoch 55/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0411 - root_mean_squared_error: 0.2027 - val_loss: 0.2784 - val_root_mean_squared_error: 0.5276
# Epoch 56/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0390 - root_mean_squared_error: 0.1975 - val_loss: 0.3071 - val_root_mean_squared_error: 0.5542
# Epoch 57/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0371 - root_mean_squared_error: 0.1927 - val_loss: 0.2987 - val_root_mean_squared_error: 0.5465
# Epoch 58/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0334 - root_mean_squared_error: 0.1827 - val_loss: 0.2987 - val_root_mean_squared_error: 0.5466
# Epoch 59/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.3019 - val_root_mean_squared_error: 0.5494
# Epoch 60/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0270 - root_mean_squared_error: 0.1643 - val_loss: 0.2872 - val_root_mean_squared_error: 0.5359
# Epoch 61/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.3080 - val_root_mean_squared_error: 0.5549
# Epoch 62/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520 - val_loss: 0.3007 - val_root_mean_squared_error: 0.5483
# Epoch 63/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496 - val_loss: 0.2937 - val_root_mean_squared_error: 0.5419
# Epoch 64/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0191 - root_mean_squared_error: 0.1383 - val_loss: 0.3036 - val_root_mean_squared_error: 0.5510
# Epoch 65/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.3104 - val_root_mean_squared_error: 0.5572
# Epoch 66/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.3013 - val_root_mean_squared_error: 0.5489
# Epoch 67/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.3050 - val_root_mean_squared_error: 0.5523
# Epoch 68/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.3094 - val_root_mean_squared_error: 0.5563
# Epoch 69/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966 - val_loss: 0.2982 - val_root_mean_squared_error: 0.5461
# Epoch 70/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - val_loss: 0.3068 - val_root_mean_squared_error: 0.5539
# Epoch 71/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.3066 - val_root_mean_squared_error: 0.5537
# Epoch 72/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.3210 - val_root_mean_squared_error: 0.5666
# Epoch 73/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.3172 - val_root_mean_squared_error: 0.5632
# Epoch 74/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0062 - root_mean_squared_error: 0.0788 - val_loss: 0.3072 - val_root_mean_squared_error: 0.5543
# Epoch 75/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.3005 - val_root_mean_squared_error: 0.5482
# Epoch 76/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.3100 - val_root_mean_squared_error: 0.5568
# Epoch 77/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.3072 - val_root_mean_squared_error: 0.5542
# Epoch 78/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0061 - root_mean_squared_error: 0.0784 - val_loss: 0.3140 - val_root_mean_squared_error: 0.5604
# Epoch 79/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.3056 - val_root_mean_squared_error: 0.5528
# Epoch 80/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0057 - root_mean_squared_error: 0.0758 - val_loss: 0.3069 - val_root_mean_squared_error: 0.5540
# Epoch 81/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0048 - root_mean_squared_error: 0.0696 - val_loss: 0.3040 - val_root_mean_squared_error: 0.5513
# Epoch 82/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.3108 - val_root_mean_squared_error: 0.5575
# Epoch 83/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645 - val_loss: 0.2998 - val_root_mean_squared_error: 0.5475
# Epoch 84/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0038 - root_mean_squared_error: 0.0616 - val_loss: 0.3095 - val_root_mean_squared_error: 0.5563
# Epoch 85/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0039 - root_mean_squared_error: 0.0622 - val_loss: 0.3061 - val_root_mean_squared_error: 0.5533
# Epoch 86/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.3013 - val_root_mean_squared_error: 0.5489
# Epoch 87/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - root_mean_squared_error: 0.0543 - val_loss: 0.3069 - val_root_mean_squared_error: 0.5540
# Epoch 88/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0023 - root_mean_squared_error: 0.0483 - val_loss: 0.3070 - val_root_mean_squared_error: 0.5541
# Epoch 89/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.3066 - val_root_mean_squared_error: 0.5537
# Epoch 90/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.3065 - val_root_mean_squared_error: 0.5536
# Epoch 91/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0032 - root_mean_squared_error: 0.0566 - val_loss: 0.2977 - val_root_mean_squared_error: 0.5456
# Epoch 92/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.3018 - val_root_mean_squared_error: 0.5494
# Epoch 93/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0025 - root_mean_squared_error: 0.0498 - val_loss: 0.3035 - val_root_mean_squared_error: 0.5509
# Epoch 94/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0033 - root_mean_squared_error: 0.0574 - val_loss: 0.3000 - val_root_mean_squared_error: 0.5477
# Epoch 95/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0033 - root_mean_squared_error: 0.0574 - val_loss: 0.3053 - val_root_mean_squared_error: 0.5526
# Epoch 96/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.3134 - val_root_mean_squared_error: 0.5598
# Epoch 97/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.3136 - val_root_mean_squared_error: 0.5600
# Epoch 98/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0044 - root_mean_squared_error: 0.0666 - val_loss: 0.3061 - val_root_mean_squared_error: 0.5533
# Epoch 99/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0049 - root_mean_squared_error: 0.0696 - val_loss: 0.3063 - val_root_mean_squared_error: 0.5534
# Epoch 100/200
#  1/30 [>.............................] - ETA: 0s - loss: 0.0039 - root_mean_squared_error: 0.0627
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a6914edfe3b7> in <module>()
#      60 )
#      61
# ---> 62 DenseModel.fit(x_train, y_train, epochs=200,validation_data=(x_val,y_val),batch_size=20)
#      63 model=DenseModel
#      64 print("Validation error: ",mean_squared_error(y_val,model.predict(x_val),squared=False))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
DenseModel.save('/content/drive/MyDrive/aware_train_2022/models/DMbest')
x_test=[getmatrix(user,pred_test) for user in pred_test]
result_Dense=DenseModel.predict(x_test)
def save_result(result,name):
  dictdata={}
  for row,user in zip(result,pred_test):
    dictdata[user]={}
    dictdata[user]["acc"]=str(row[0])
    dictdata[user]["bank"] = str(row[1])
    dictdata[user]["it"] = str(row[2])
    dictdata[user]["wait"] = str(row[3])
  with open('/content/drive/MyDrive/aware_train_2022/output/'+name, 'w') as f:
      json.dump(dictdata, f)
save_result(result_Dense,"DenseModel.json")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/aware_train_2022/models/DMbest/assets

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras import datasets, layers, models



def getmatrix(user,pred): #for flattened 9columns, append each image { visual_concept{acc,it, bank,wait},confidence,4 points} 
  images=[img for img in pred[user]]
  matrix=[]
  for img in images:
    VCs=[s for s in pred[user][img]] #gets the strings{VC,confidence,4 points} inside image
    for VC in VCs:
      row=VC.split(" ")
      VC_name= row[0]
      scores=[]
      try: #some VC not found in class_score
        scores=[float(classes_score[VC_name]["acc"]),float(classes_score[VC_name]["it"]),float(classes_score[VC_name]["bank"]),float(classes_score[VC_name]["wait"])] #[it for k2,it in classes_score[row[0]].items()]
      except:
        scores=[-1,-1,-1,-1]
      for i in range(1,2):
        scores.append(float(row[i]))
      matrix.append(scores[:])
  while(len(matrix)<=300):
    matrix.append([-1]*5)
  flatten_list = matrix

  return flatten_list

x_train=[getmatrix(user,pred_train) for user in pred_train]
y_train=[]
y_train1,y_train2,y_train3,y_train4=[],[],[],[]
for user in gt_train:
  y_train.append([float(gt_train[user]["acc"]),float(gt_train[user]["it"]),float(gt_train[user]["bank"]),float(gt_train[user]["wait"])])


x_val=[getmatrix(user,pred_val) for user in pred_val]

y_val=[]
for user in gt_val:
  y_val.append([float(gt_val[user]["acc"]),float(gt_val[user]["it"]),float(gt_val[user]["bank"]),float(gt_val[user]["wait"])])


model = models.Sequential()
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(4))


model.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=Adam(),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

model.fit(x_train, y_train, epochs=100,validation_data=(x_val,y_val),batch_size=40)
print("Validation error: ",mean_squared_error(y_val,model.predict(x_val),squared=False))
print("Train Error",mean_squared_error(y_train,model.predict(x_train),squared=False))
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.9296 - root_mean_squared_error: 0.9641 - val_loss: 0.3664 - val_root_mean_squared_error: 0.6053
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3037 - root_mean_squared_error: 0.5511 - val_loss: 0.3080 - val_root_mean_squared_error: 0.5549
# Epoch 3/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2532 - root_mean_squared_error: 0.5031 - val_loss: 0.2804 - val_root_mean_squared_error: 0.5295
# Epoch 4/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2305 - root_mean_squared_error: 0.4801 - val_loss: 0.2741 - val_root_mean_squared_error: 0.5236
# Epoch 5/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2167 - root_mean_squared_error: 0.4655 - val_loss: 0.2724 - val_root_mean_squared_error: 0.5219
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2040 - root_mean_squared_error: 0.4517 - val_loss: 0.2721 - val_root_mean_squared_error: 0.5216
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1920 - root_mean_squared_error: 0.4382 - val_loss: 0.2778 - val_root_mean_squared_error: 0.5270
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1849 - root_mean_squared_error: 0.4299 - val_loss: 0.2914 - val_root_mean_squared_error: 0.5398
# Epoch 9/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1755 - root_mean_squared_error: 0.4189 - val_loss: 0.2814 - val_root_mean_squared_error: 0.5304
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1681 - root_mean_squared_error: 0.4100 - val_loss: 0.2784 - val_root_mean_squared_error: 0.5276
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1609 - root_mean_squared_error: 0.4012 - val_loss: 0.2855 - val_root_mean_squared_error: 0.5344
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1538 - root_mean_squared_error: 0.3922 - val_loss: 0.2852 - val_root_mean_squared_error: 0.5340
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1465 - root_mean_squared_error: 0.3828 - val_loss: 0.2968 - val_root_mean_squared_error: 0.5448
# Epoch 14/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1406 - root_mean_squared_error: 0.3750 - val_loss: 0.2980 - val_root_mean_squared_error: 0.5459
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1359 - root_mean_squared_error: 0.3686 - val_loss: 0.2865 - val_root_mean_squared_error: 0.5352
# Epoch 16/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1295 - root_mean_squared_error: 0.3599 - val_loss: 0.2931 - val_root_mean_squared_error: 0.5414
# Epoch 17/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1241 - root_mean_squared_error: 0.3523 - val_loss: 0.2968 - val_root_mean_squared_error: 0.5448
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1172 - root_mean_squared_error: 0.3423 - val_loss: 0.3071 - val_root_mean_squared_error: 0.5542
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1132 - root_mean_squared_error: 0.3365 - val_loss: 0.2960 - val_root_mean_squared_error: 0.5441
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1065 - root_mean_squared_error: 0.3264 - val_loss: 0.2956 - val_root_mean_squared_error: 0.5437
# Epoch 21/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1011 - root_mean_squared_error: 0.3179 - val_loss: 0.3039 - val_root_mean_squared_error: 0.5513
# Epoch 22/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0995 - root_mean_squared_error: 0.3155 - val_loss: 0.3120 - val_root_mean_squared_error: 0.5585
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0995 - root_mean_squared_error: 0.3154 - val_loss: 0.3137 - val_root_mean_squared_error: 0.5601
# Epoch 24/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0915 - root_mean_squared_error: 0.3026 - val_loss: 0.3061 - val_root_mean_squared_error: 0.5532
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0853 - root_mean_squared_error: 0.2921 - val_loss: 0.3095 - val_root_mean_squared_error: 0.5564
# Epoch 26/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0810 - root_mean_squared_error: 0.2845 - val_loss: 0.3110 - val_root_mean_squared_error: 0.5577
# Epoch 27/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0773 - root_mean_squared_error: 0.2781 - val_loss: 0.3155 - val_root_mean_squared_error: 0.5617
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0732 - root_mean_squared_error: 0.2705 - val_loss: 0.3281 - val_root_mean_squared_error: 0.5728
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0725 - root_mean_squared_error: 0.2693 - val_loss: 0.3263 - val_root_mean_squared_error: 0.5712
# Epoch 30/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0689 - root_mean_squared_error: 0.2624 - val_loss: 0.3249 - val_root_mean_squared_error: 0.5700
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0659 - root_mean_squared_error: 0.2568 - val_loss: 0.3212 - val_root_mean_squared_error: 0.5667
# Epoch 32/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0637 - root_mean_squared_error: 0.2523 - val_loss: 0.3380 - val_root_mean_squared_error: 0.5814
# Epoch 33/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0621 - root_mean_squared_error: 0.2491 - val_loss: 0.3287 - val_root_mean_squared_error: 0.5733
# Epoch 34/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0606 - root_mean_squared_error: 0.2461 - val_loss: 0.3271 - val_root_mean_squared_error: 0.5720
# Epoch 35/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0566 - root_mean_squared_error: 0.2380 - val_loss: 0.3385 - val_root_mean_squared_error: 0.5818
# Epoch 36/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0554 - root_mean_squared_error: 0.2354 - val_loss: 0.3343 - val_root_mean_squared_error: 0.5781
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0549 - root_mean_squared_error: 0.2344 - val_loss: 0.3376 - val_root_mean_squared_error: 0.5810
# Epoch 38/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0519 - root_mean_squared_error: 0.2279 - val_loss: 0.3402 - val_root_mean_squared_error: 0.5832
# Epoch 39/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0483 - root_mean_squared_error: 0.2197 - val_loss: 0.3368 - val_root_mean_squared_error: 0.5803
# Epoch 40/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0459 - root_mean_squared_error: 0.2143 - val_loss: 0.3441 - val_root_mean_squared_error: 0.5866
# Epoch 41/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0441 - root_mean_squared_error: 0.2100 - val_loss: 0.3402 - val_root_mean_squared_error: 0.5832
# Epoch 42/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0432 - root_mean_squared_error: 0.2077 - val_loss: 0.3512 - val_root_mean_squared_error: 0.5926
# Epoch 43/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0422 - root_mean_squared_error: 0.2054 - val_loss: 0.3434 - val_root_mean_squared_error: 0.5860
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0426 - root_mean_squared_error: 0.2063 - val_loss: 0.3399 - val_root_mean_squared_error: 0.5830
# Epoch 45/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0393 - root_mean_squared_error: 0.1983 - val_loss: 0.3421 - val_root_mean_squared_error: 0.5849
# Epoch 46/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0377 - root_mean_squared_error: 0.1941 - val_loss: 0.3517 - val_root_mean_squared_error: 0.5931
# Epoch 47/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0364 - root_mean_squared_error: 0.1909 - val_loss: 0.3485 - val_root_mean_squared_error: 0.5903
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0354 - root_mean_squared_error: 0.1882 - val_loss: 0.3473 - val_root_mean_squared_error: 0.5893
# Epoch 49/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0334 - root_mean_squared_error: 0.1829 - val_loss: 0.3486 - val_root_mean_squared_error: 0.5904
# Epoch 50/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0321 - root_mean_squared_error: 0.1792 - val_loss: 0.3501 - val_root_mean_squared_error: 0.5917
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0305 - root_mean_squared_error: 0.1746 - val_loss: 0.3534 - val_root_mean_squared_error: 0.5945
# Epoch 52/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0297 - root_mean_squared_error: 0.1724 - val_loss: 0.3529 - val_root_mean_squared_error: 0.5941
# Epoch 53/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0296 - root_mean_squared_error: 0.1721 - val_loss: 0.3578 - val_root_mean_squared_error: 0.5981
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0297 - root_mean_squared_error: 0.1722 - val_loss: 0.3571 - val_root_mean_squared_error: 0.5975
# Epoch 55/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0281 - root_mean_squared_error: 0.1676 - val_loss: 0.3582 - val_root_mean_squared_error: 0.5985
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0270 - root_mean_squared_error: 0.1642 - val_loss: 0.3601 - val_root_mean_squared_error: 0.6000
# Epoch 57/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0254 - root_mean_squared_error: 0.1595 - val_loss: 0.3541 - val_root_mean_squared_error: 0.5950
# Epoch 58/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0258 - root_mean_squared_error: 0.1607 - val_loss: 0.3583 - val_root_mean_squared_error: 0.5986
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - val_loss: 0.3589 - val_root_mean_squared_error: 0.5990
# Epoch 60/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0234 - root_mean_squared_error: 0.1529 - val_loss: 0.3632 - val_root_mean_squared_error: 0.6026
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0219 - root_mean_squared_error: 0.1479 - val_loss: 0.3636 - val_root_mean_squared_error: 0.6030
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0213 - root_mean_squared_error: 0.1460 - val_loss: 0.3693 - val_root_mean_squared_error: 0.6077
# Epoch 63/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0206 - root_mean_squared_error: 0.1434 - val_loss: 0.3634 - val_root_mean_squared_error: 0.6029
# Epoch 64/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0201 - root_mean_squared_error: 0.1419 - val_loss: 0.3616 - val_root_mean_squared_error: 0.6013
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0199 - root_mean_squared_error: 0.1410 - val_loss: 0.3689 - val_root_mean_squared_error: 0.6073
# Epoch 66/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0193 - root_mean_squared_error: 0.1389 - val_loss: 0.3671 - val_root_mean_squared_error: 0.6059
# Epoch 67/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0183 - root_mean_squared_error: 0.1353 - val_loss: 0.3715 - val_root_mean_squared_error: 0.6095
# Epoch 68/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0175 - root_mean_squared_error: 0.1323 - val_loss: 0.3698 - val_root_mean_squared_error: 0.6081
# Epoch 69/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1306 - val_loss: 0.3690 - val_root_mean_squared_error: 0.6074
# Epoch 70/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0171 - root_mean_squared_error: 0.1308 - val_loss: 0.3719 - val_root_mean_squared_error: 0.6099
# Epoch 71/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329 - val_loss: 0.3788 - val_root_mean_squared_error: 0.6154
# Epoch 72/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0172 - root_mean_squared_error: 0.1313 - val_loss: 0.3778 - val_root_mean_squared_error: 0.6147
# Epoch 73/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.3727 - val_root_mean_squared_error: 0.6105
# Epoch 74/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.3814 - val_root_mean_squared_error: 0.6175
# Epoch 75/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - val_loss: 0.3748 - val_root_mean_squared_error: 0.6122
# Epoch 76/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.1204 - val_loss: 0.3787 - val_root_mean_squared_error: 0.6154
# Epoch 77/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.3760 - val_root_mean_squared_error: 0.6132
# Epoch 78/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.3812 - val_root_mean_squared_error: 0.6174
# Epoch 79/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0138 - root_mean_squared_error: 0.1173 - val_loss: 0.3843 - val_root_mean_squared_error: 0.6200
# Epoch 80/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.3844 - val_root_mean_squared_error: 0.6200
# Epoch 81/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165 - val_loss: 0.3830 - val_root_mean_squared_error: 0.6189
# Epoch 82/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0138 - root_mean_squared_error: 0.1177 - val_loss: 0.3829 - val_root_mean_squared_error: 0.6188
# Epoch 83/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157 - val_loss: 0.3821 - val_root_mean_squared_error: 0.6182
# Epoch 84/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123 - val_loss: 0.3848 - val_root_mean_squared_error: 0.6204
# Epoch 85/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126 - val_loss: 0.3839 - val_root_mean_squared_error: 0.6196
# Epoch 86/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0133 - root_mean_squared_error: 0.1154 - val_loss: 0.3889 - val_root_mean_squared_error: 0.6237
# Epoch 87/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.3844 - val_root_mean_squared_error: 0.6200
# Epoch 88/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107 - val_loss: 0.3816 - val_root_mean_squared_error: 0.6177
# Epoch 89/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.3920 - val_root_mean_squared_error: 0.6261
# Epoch 90/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.3936 - val_root_mean_squared_error: 0.6274
# Epoch 91/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0124 - root_mean_squared_error: 0.1111 - val_loss: 0.3870 - val_root_mean_squared_error: 0.6221
# Epoch 92/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095 - val_loss: 0.3879 - val_root_mean_squared_error: 0.6228
# Epoch 93/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.3901 - val_root_mean_squared_error: 0.6246
# Epoch 94/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0114 - root_mean_squared_error: 0.1068 - val_loss: 0.3954 - val_root_mean_squared_error: 0.6288
# Epoch 95/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - val_loss: 0.3913 - val_root_mean_squared_error: 0.6255
# Epoch 96/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263 - val_loss: 0.3871 - val_root_mean_squared_error: 0.6222
# Epoch 97/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0188 - root_mean_squared_error: 0.1372 - val_loss: 0.4069 - val_root_mean_squared_error: 0.6379
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314 - val_loss: 0.3963 - val_root_mean_squared_error: 0.6295
# Epoch 99/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.3974 - val_root_mean_squared_error: 0.6304
# Epoch 100/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278 - val_loss: 0.4045 - val_root_mean_squared_error: 0.6360
# Validation error:  0.6341913370014286
# Train Error 0.1359502260431074
